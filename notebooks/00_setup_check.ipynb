# %%
from pathlib import Path
import os
import sys
import json
import random

import numpy as np
import pandas as pd

import torch
import torchvision

# %%
PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print("Current Directory:")
print(Path.cwd())

print("\nProject Root Directory:")
print(PROJECT_ROOT)
# Out:
# Current Directory:
# c:\Users\ASUS\dev\projects\satellite-project\notebooks
#
# Project Root Directory:
# c:\Users\ASUS\dev\projects\satellite-project

# %%
DATA_DIR = PROJECT_ROOT / "data"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
CHECKPOINT_DIR = PROJECT_ROOT / "checkpoints"
REPORT_DIR = PROJECT_ROOT / "reports"

EUROSAT_DIR = DATA_DIR / "eurosat"
UCMERCED_DIR = DATA_DIR / "ucmerced"

print("Data Directory:", DATA_DIR)
print("EuroSAT Directory:", EUROSAT_DIR)
print("UC Merced Directory:", UCMERCED_DIR)
# Out:
# Data Directory: c:\Users\ASUS\dev\projects\satellite-project\data
# EuroSAT Directory: c:\Users\ASUS\dev\projects\satellite-project\data\eurosat
# UC Merced Directory: c:\Users\ASUS\dev\projects\satellite-project\data\ucmerced

# %%
print("=" * 60)
print("PyTorch Version:", torch.__version__)
print("Torchvision Version:", torchvision.__version__)
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 60)
# Out:
# ...
# PyTorch Version: 2.11.0+cu128
# Torchvision Version: 0.26.0+cu128
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 5070 Ti Laptop GPU
# ...

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)

print(f"Random Seed = {SEED}")
# Out:
# Random Seed = 42

# %%
required_dirs = [
    "app",
    "checkpoints",
    "data",
    "data/eurosat",
    "data/processed",
    "data/ucmerced",
    "notebooks",
    "outputs",
    "outputs/confusion_matrices",
    "outputs/embeddings",
    "outputs/figures",
    "outputs/heatmaps",
    "reports",
    "src",
    "tests"
]

for directory in required_dirs:
    path = PROJECT_ROOT / directory

    if path.exists():
        print(f"[OK] {directory}")
    else:
        print(f"[MISSING] {directory}")
# Out:
# [OK] app
# [OK] checkpoints
# [OK] data
# [OK] data/eurosat
# [OK] data/processed
# [OK] data/ucmerced
# [OK] notebooks
# [OK] outputs
# [OK] outputs/confusion_matrices
# [OK] outputs/embeddings
# [OK] outputs/figures
# [OK] outputs/heatmaps
# [OK] reports
# [OK] src
# [OK] tests

# %%
print("EuroSAT Exists:", EUROSAT_DIR.exists())
print("UC Merced Exists:", UCMERCED_DIR.exists())
# Out:
# EuroSAT Exists: True
# UC Merced Exists: True

# %%
print("EuroSAT Contents:\n")

for item in EUROSAT_DIR.iterdir():
    print(item.name)
# Out:
# EuroSAT Contents:
#
# EuroSAT
# EuroSATallBands

# %%
print("UC Merced Contents:\n")

for item in UCMERCED_DIR.iterdir():
    print(item.name)
# Out:
# UC Merced Contents:
#
# Images
# readme.txt
# readme.txt.bak

# %%
eurosat_files = list(EUROSAT_DIR.rglob("*"))
ucmerced_files = list(UCMERCED_DIR.rglob("*"))

print("EuroSAT Total Files:", len(eurosat_files))
print("UC Merced Total Files:", len(ucmerced_files))
# Out:
# EuroSAT Total Files: 54627
# UC Merced Total Files: 2124

# %%
test_data = {
    "project": "satellite-land-use-classification",
    "status": "setup_complete"
}

checkpoint_file = CHECKPOINT_DIR / "setup_test.json"

with open(checkpoint_file, "w") as f:
    json.dump(test_data, f, indent=4)

print(f"Checkpoint saved to:\n{checkpoint_file}")
# Out:
# Checkpoint saved to:
# c:\Users\ASUS\dev\projects\satellite-project\checkpoints\setup_test.json

# %%
if torch.cuda.is_available():

    x = torch.rand(5000, 5000, device="cuda")
    y = torch.mm(x, x)

    print("Tensor Device:", y.device)
    print(
        "VRAM Allocated (GB):",
        round(torch.cuda.memory_allocated() / 1e9, 2)
    )
# Out:
# Tensor Device: cuda:0
# VRAM Allocated (GB): 0.21
