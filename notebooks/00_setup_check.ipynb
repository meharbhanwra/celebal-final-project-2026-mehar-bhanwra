# %%
import os
import random
from pathlib import Path

import numpy as np
import pandas as pd

import torch
import torchvision

# %%
print("=" * 50)
print("PyTorch Version:", torch.__version__)
print("Torchvision Version:", torchvision.__version__)
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("=" * 50)
# Out:
# ...
# PyTorch Version: 2.11.0+cu128
# Torchvision Version: 0.26.0+cu128
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 5070 Ti Laptop GPU
# ...

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)

print(f"Seed set to {SEED}")
# Out:
# Seed set to 42

# %%
project_dirs = [
    "app",
    "checkpoints",
    "data",
    "data/eurosat",
    "data/ucmerced",
    "data/processed",
    "notebooks",
    "outputs",
    "outputs/confusion_matrices",
    "outputs/embeddings",
    "outputs/figures",
    "outputs/heatmaps",
    "reports",
    "src",
    "tests"
]

for directory in project_dirs:
    Path(directory).mkdir(parents=True, exist_ok=True)

print("Directory check complete.")
# Out:
# Directory check complete.

# %%
eurosat_path = Path("data/eurosat")
ucmerced_path = Path("data/ucmerced")

print("EuroSAT Exists:", eurosat_path.exists())
print("UC Merced Exists:", ucmerced_path.exists())
# Out:
# EuroSAT Exists: True
# UC Merced Exists: True

# %%
from pathlib import Path

eurosat_images = list(Path("data/eurosat").rglob("*.*"))
ucmerced_images = list(Path("data/ucmerced").rglob("*.*"))

print("EuroSAT Files:", len(eurosat_images))
print("UC Merced Files:", len(ucmerced_images))
# Out:
# EuroSAT Files: 0
# UC Merced Files: 0

# %%
import json

test_file = {
    "project": "satellite-land-use-classification",
    "status": "setup_complete"
}

with open("checkpoints/setup_test.json", "w") as f:
    json.dump(test_file, f)

print("Checkpoint write successful.")
# Out:
# Checkpoint write successful.

# %%
from pathlib import Path

for item in Path("data/eurosat").rglob("*"):
    print(item)

# %%
from pathlib import Path

len(list(Path("data/ucmerced").rglob("*.tif")))
# Out:
# 0

# %%
from pathlib import Path

for ext in ["*.jpg", "*.png", "*.tif", "*.tiff"]:
    print(ext, len(list(Path("data/ucmerced").rglob(ext))))
# Out:
# *.jpg 0
# *.png 0
# *.tif 0
# *.tiff 0

# %%
from pathlib import Path
import os

print("CWD:")
print(os.getcwd())

print("\nRoot Contents:")
for item in Path(".").iterdir():
    print(item)

print("\nData Exists:")
print(Path("data").exists())

print("\nParent Data Exists:")
print(Path("../data").exists())
# Out:
# CWD:
# c:\Users\ASUS\dev\projects\satellite-project\notebooks
#
# Root Contents:
# 00_setup_check.ipynb
# 01_dataset_eda.ipynb
# app
# checkpoints
# data
# notebooks
# outputs
# reports
# src
# tests
#
# Data Exists:
# True
#
# Parent Data Exists:
# True
